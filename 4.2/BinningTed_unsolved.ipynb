# %%
# Import Dependencies
import pandas as pd

# %%
# Create a path to the csv and read it into a Pandas DataFrame
csv_path = "../Resources/ted_talks.csv"
ted_df = pd.read_csv(csv_path)
ted_df.head()
# Out:
#    comments                                        description  duration  \
# 0      4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1       265  With the same humor and humanity he exuded in ...       977
# 2       124  New York Times columnist David Pogue takes aim...      1286
# 3       200  In an emotionally charged talk, MacArthur-winn...      1116
# 4       593  You've never seen data presented like this. Wi...      1190
#
#      event  languages   main_speaker  \
# 0  TED2006         60   Ken Robinson
# 1  TED2006         43        Al Gore
# 2  TED2006         26    David Pogue
# 3  TED2006         35  Majora Carter
# 4  TED2006         48   Hans Rosling
#
#                                             name  \
# 0      Ken Robinson: Do schools kill creativity?
# 1           Al Gore: Averting the climate crisis
# 2                  David Pogue: Simplicity sells
# 3             Majora Carter: Greening the ghetto
# 4  Hans Rosling: The best stats you've ever seen
#
#                              title     views
# 0      Do schools kill creativity?  47227110
# 1      Averting the climate crisis   3200520
# 2                 Simplicity sells   1636292
# 3              Greening the ghetto   1697550
# 4  The best stats you've ever seen  12005869

# %%
# Figure out the minimum and maximum views for a TED Talk
ted_df.max()['views']
# Out:
# 47227110

# %%
ted_df.min()['views']
# Out:
# 50443

# %%
ted_df.describe()
# Out:
#           comments     duration    languages         views
# count  2550.000000  2550.000000  2550.000000  2.550000e+03
# mean    191.562353   826.510196    27.326275  1.698297e+06
# std     282.315223   374.009138     9.563452  2.498479e+06
# min       2.000000   135.000000     0.000000  5.044300e+04
# 25%      63.000000   577.000000    23.000000  7.557928e+05
# 50%     118.000000   848.000000    28.000000  1.124524e+06
# 75%     221.750000  1046.750000    33.000000  1.700760e+06
# max    6404.000000  5256.000000    72.000000  4.722711e+07

# %%
# Create bins in which to place values based upon TED Talk views
bins = [0, 199999, 399999, 599999, 799999, 999999, 1999999, 2999999, 3999999, 4999999,50000000]

# Create labels for these bins
group_labels = ["0 to 199k", "200k to 399k", "400k to 599k", "600k to 799k", "800k to 999k", "1mil to 2mil", "2mil to 3mil", "3mil to 4mil", "4mil to 5mil", "5mil to 50mil"]

# %%
# Slice the data and place it into bins
pd.cut(ted_df["views"], bins, labels = group_labels).head()
# Out:
# 0    5mil to 50mil
# 1     3mil to 4mil
# 2     1mil to 2mil
# 3     1mil to 2mil
# 4    5mil to 50mil
# Name: views, dtype: category
# Categories (10, object): ['0 to 199k' < '200k to 399k' < '400k to 599k' < '600k to 799k' ... '2mil to 3mil' < '3mil to 4mil' < '4mil to 5mil' < '5mil to 50mil']

# %%
# Place the data series into a new column inside of the DataFrame
ted_df['View Group'] = pd.cut(ted_df["views"], bins, labels = group_labels)
ted_df
# Out:
#       comments                                        description  duration  \
# 0         4553  Sir Ken Robinson makes an entertaining and pro...      1164
# 1          265  With the same humor and humanity he exuded in ...       977
# 2          124  New York Times columnist David Pogue takes aim...      1286
# 3          200  In an emotionally charged talk, MacArthur-winn...      1116
# 4          593  You've never seen data presented like this. Wi...      1190
# ...        ...                                                ...       ...
# 2545        17  Between 2008 and 2016, the United States depor...       476
# 2546         6  How can you study Mars without a spaceship? He...       290
# 2547        10  Science fiction visions of the future show us ...       651
# 2548        32  In an unmissable talk about race and politics ...      1100
# 2549         8  With more than half of the world population li...       519
#
#              event  languages         main_speaker  \
# 0          TED2006         60         Ken Robinson
# 1          TED2006         43              Al Gore
# 2          TED2006         26          David Pogue
# 3          TED2006         35        Majora Carter
# 4          TED2006         48         Hans Rosling
# ...            ...        ...                  ...
# 2545       TED2017          4     Duarte Geraldino
# 2546       TED2017          3  Armando Azua-Bustos
# 2547       TED2017          1       Radhika Nagpal
# 2548  TEDxMileHigh          1     Theo E.J. Wilson
# 2549       TED2017          1    Karoliina Korppoo
#
#                                                    name  \
# 0             Ken Robinson: Do schools kill creativity?
# 1                  Al Gore: Averting the climate crisis
# 2                         David Pogue: Simplicity sells
# 3                    Majora Carter: Greening the ghetto
# 4         Hans Rosling: The best stats you've ever seen
# ...                                                 ...
# 2545  Duarte Geraldino: What we're missing in the de...
# 2546  Armando Azua-Bustos: The most Martian place on...
# 2547  Radhika Nagpal: What intelligent machines can ...
# 2548  Theo E.J. Wilson: A black man goes undercover ...
# 2549  Karoliina Korppoo: How a video game might help...
#
#                                                   title     views  \
# 0                           Do schools kill creativity?  47227110
# 1                           Averting the climate crisis   3200520
# 2                                      Simplicity sells   1636292
# 3                                   Greening the ghetto   1697550
# 4                       The best stats you've ever seen  12005869
# ...                                                 ...       ...
# 2545  What we're missing in the debate about immigra...    450430
# 2546                    The most Martian place on Earth    417470
# 2547  What intelligent machines can learn from a sch...    375647
# 2548       A black man goes undercover in the alt-right    419309
# 2549  How a video game might help us build better ci...    391721
#
#          View Group
# 0     5mil to 50mil
# 1      3mil to 4mil
# 2      1mil to 2mil
# 3      1mil to 2mil
# 4     5mil to 50mil
# ...             ...
# 2545   400k to 599k
# 2546   400k to 599k
# 2547   200k to 399k
# 2548   400k to 599k
# 2549   200k to 399k
#
# [2550 rows x 10 columns]

# %%
# Create a GroupBy object based upon "View Group"
view_group_df = ted_df.groupby(['View Group'])
view_group_df.first()
# Out:
#                comments                                        description  \
# View Group
# 0 to 199k            43  Singer-songwriter Rokia Traore performs "Kouna...
# 200k to 399k         55  Jehane Noujaim unveils her 2006 TED Prize wish...
# 400k to 599k         50  The founding mother of the blog revolution, Mo...
# 600k to 799k         71  Accepting the 2006 TED Prize, Dr. Larry Brilli...
# 800k to 999k         46  Architect Joshua Prince-Ramus takes the audien...
# 1mil to 2mil        124  New York Times columnist David Pogue takes aim...
# 2mil to 3mil        852  Philosopher Dan Dennett calls for religion -- ...
# 3mil to 4mil        265  With the same humor and humanity he exuded in ...
# 4mil to 5mil        242  Jeff Han shows off a cheap, scalable multi-tou...
# 5mil to 50mil      4553  Sir Ken Robinson makes an entertaining and pro...
#
#                duration           event  languages         main_speaker  \
# View Group
# 0 to 199k           386  TEDGlobal 2007          0         Rokia Traore
# 200k to 399k       1538         TED2006         20       Jehane Noujaim
# 400k to 599k       1006         TED2006         20           Mena Trott
# 600k to 799k       1550         TED2006         24      Larry Brilliant
# 800k to 999k       1198         TED2006         19  Joshua Prince-Ramus
# 1mil to 2mil       1286         TED2006         26          David Pogue
# 2mil to 3mil       1485         TED2006         32          Dan Dennett
# 3mil to 4mil        977         TED2006         43              Al Gore
# 4mil to 5mil        527         TED2006         27             Jeff Han
# 5mil to 50mil      1164         TED2006         60         Ken Robinson
#
#                                                             name  \
# View Group
# 0 to 199k                               Rokia Traore: "Kounandi"
# 200k to 399k       Jehane Noujaim: My wish: A global day of film
# 400k to 599k   Mena Trott: Meet the founder of the blog revol...
# 600k to 799k    Larry Brilliant: My wish: Help me stop pandemics
# 800k to 999k   Joshua Prince-Ramus: Behind the design of Seat...
# 1mil to 2mil                       David Pogue: Simplicity sells
# 2mil to 3mil   Dan Dennett: Let's teach religion -- all relig...
# 3mil to 4mil                Al Gore: Averting the climate crisis
# 4mil to 5mil   Jeff Han: The radical promise of the multi-tou...
# 5mil to 50mil          Ken Robinson: Do schools kill creativity?
#
#                                                            title     views
# View Group
# 0 to 199k                                             "Kounandi"     82488
# 200k to 399k                       My wish: A global day of film    387877
# 400k to 599k             Meet the founder of the blog revolution    518624
# 600k to 799k                     My wish: Help me stop pandemics    693341
# 800k to 999k              Behind the design of Seattle's library    967741
# 1mil to 2mil                                    Simplicity sells   1636292
# 2mil to 3mil   Let's teach religion -- all religion -- in sch...   2567958
# 3mil to 4mil                         Averting the climate crisis   3200520
# 4mil to 5mil    The radical promise of the multi-touch interface   4531020
# 5mil to 50mil                        Do schools kill creativity?  47227110

# %%
# Find how many rows fall into each bin
view_group_count = ted_df.groupby(['View Group']).count()["name"]
view_group_count
# Out:
# View Group
# 0 to 199k          32
# 200k to 399k      135
# 400k to 599k      234
# 600k to 799k      307
# 800k to 999k      339
# 1mil to 2mil     1004
# 2mil to 3mil      239
# 3mil to 4mil       93
# 4mil to 5mil       68
# 5mil to 50mil      99
# Name: name, dtype: int64

# %%
# Get the average of each column within the GroupBy object
average_comments = ted_df.groupby(['View Group']).mean()['comments']
average_duration = ted_df.groupby(['View Group']).mean()['duration']
average_languages = ted_df.groupby(['View Group']).mean()['languages']
average_views = ted_df.groupby(['View Group']).mean()['views']

# %%
average_comments
# Out:
# View Group
# 0 to 199k         76.937500
# 200k to 399k      81.992593
# 400k to 599k     107.162393
# 600k to 799k     118.912052
# 800k to 999k     119.628319
# 1mil to 2mil     168.136454
# 2mil to 3mil     299.481172
# 3mil to 4mil     360.870968
# 4mil to 5mil     507.088235
# 5mil to 50mil    650.393939
# Name: comments, dtype: float64

# %%
average_duration
# Out:
# View Group
# 0 to 199k        898.187500
# 200k to 399k     832.192593
# 400k to 599k     870.517094
# 600k to 799k     829.039088
# 800k to 999k     798.772861
# 1mil to 2mil     809.899402
# 2mil to 3mil     832.430962
# 3mil to 4mil     809.505376
# 4mil to 5mil     920.514706
# 5mil to 50mil    884.282828
# Name: duration, dtype: float64

# %%
average_languages
# Out:
# View Group
# 0 to 199k         4.062500
# 200k to 399k     18.785185
# 400k to 599k     22.940171
# 600k to 799k     24.400651
# 800k to 999k     25.678466
# 1mil to 2mil     27.899402
# 2mil to 3mil     32.807531
# 3mil to 4mil     34.258065
# 4mil to 5mil     35.720588
# 5mil to 50mil    40.252525
# Name: languages, dtype: float64

# %%
average_views
# Out:
# View Group
# 0 to 199k        1.498010e+05
# 200k to 399k     3.221191e+05
# 400k to 599k     5.038403e+05
# 600k to 799k     7.058367e+05
# 800k to 999k     9.022959e+05
# 1mil to 2mil     1.368263e+06
# 2mil to 3mil     2.390719e+06
# 3mil to 4mil     3.440350e+06
# 4mil to 5mil     4.468781e+06
# 5mil to 50mil    1.083801e+07
# Name: views, dtype: float64
